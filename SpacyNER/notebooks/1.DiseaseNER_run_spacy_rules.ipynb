# %%
# !TOKENIZERS_PARALLELISM=false

# %%
# !mkdir -p spacy_model_ner/

# %%
# !pip install tabulate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tabulate in /path/to/dir/.local/lib/python3.7/site-packages (0.8.9)
# WARNING: There was an error checking the latest version of pip.

# %%
import re
import itertools
import json
import pandas as pd

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
spacy.require_gpu()
# Out:
# True

# %% [markdown]
# #### Load sentences

# %%
UNLABELED_SENTENCE_DIR = '../data/diease_ner/unlabeled_sentences/'

# %%
sentences_df = pd.read_csv(f'{UNLABELED_SENTENCE_DIR}/complete_data_for_rules_tagging.csv',index_col=False)

# %%
sentences_df.head()
# Out:
#   New_Sentence_Id                                           Sentence
# 0            tr_0  Identification of APC2 , a homologue of the ad...
# 1            tr_1  The adenomatous polyposis coli ( APC ) tumour ...
# 2           tr_10  A common MSH2 mutation in English and North Am...
# 3          tr_100  The positive control for DMT1 up - regulation ...
# 4         tr_1000  The history further indicated intrauterine gro...

# %%
sentences_df.loc[0,'Sentence']
# Out:
# 'Identification of APC2 , a homologue of the adenomatous polyposis coli tumour suppressor .'

# %%
sentences_df.loc[2,'Sentence']
# Out:
# 'A common MSH2 mutation in English and North American HNPCC families : origin , phenotypic expression , and sex specific differences in colorectal cancer .'

# %%
sentences_df.shape
# Out:
# (7298, 2)

# %%
text = sentences_df.loc[0,'Sentence']

# %%
text
# Out:
# 'Identification of APC2 , a homologue of the adenomatous polyposis coli tumour suppressor .'

# %%
doc = nlp(text)

[(token.text, token.tag_, token.dep_) for token in doc]
# Out:
# [('Identification', 'NN', 'nsubj'),
#  ('of', 'IN', 'prep'),
#  ('APC2', 'NNP', 'pobj'),
#  (',', ',', 'punct'),
#  ('a', 'DT', 'det'),
#  ('homologue', 'NN', 'appos'),
#  ('of', 'IN', 'prep'),
#  ('the', 'DT', 'det'),
#  ('adenomatous', 'JJ', 'amod'),
#  ('polyposis', 'NN', 'pobj'),
#  ('coli', 'VBZ', 'ROOT'),
#  ('tumour', 'NN', 'compound'),
#  ('suppressor', 'NN', 'dobj'),
#  ('.', '.', 'punct')]

# %%
# !mkdir -p ../data/diease_ner/diseases_words/

# %%
with open('../data/diease_ner/diseases_words/diseases_ner.json','r') as f:
    diseases_json = json.load(f)

# %%
# !ls spacy_model_ner
# Out:
# diseases_ner.json
# diseases_ner.sjon
# split_of_classes_sentence_level.csv
# split_of_classes_sentence_level_dev.csv
# split_of_classes_sentence_level_test.csv
# split_of_classes_sentence_level_train.csv
# token_level_tags_on_one_unlabeled_sentence.csv
# token_level_tags_on_one_unlabeled_sentence_2.csv

# %%
# !cp ../data/diease_ner/diseases_words/diseases_ner.json spacy_model_ner/diseases_ner.json

# %% [markdown]
# Source for the disease words: <br>
# > thanks to Shivanshu Gupta to have crawled the below source of diseases. We can use this as a base list to produce our rules patterns
# > https://raw.githubusercontent.com/Shivanshu-Gupta/web-scrapers/master/medical_ner/medicinenet-diseases.json

# %%
diseases_json[0:5]
# Out:
# [{'disease': 'Hemophilia'},
#  {'disease': 'A, Hemophilia'},
#  {'disease': 'Hemophilia A'},
#  {'disease': 'Hepatitis A'},
#  {'disease': 'A, Hepatitis'}]

# %%
list_of_diseases = [each['disease'] for each in diseases_json if not re.search('[,]|test',each['disease'],re.I)]

# %%
print(len(diseases_json))
# Out:
# 4969

# %%
print(len(list_of_diseases))
# Out:
# 4283

# %%
list_of_diseases[0:5]
# Out:
# ['Hemophilia',
#  'Hemophilia A',
#  'Hepatitis A',
#  'Abdominal Aortic Aneurysm',
#  'AAA']

# %%
list_of_diseases.extend(['tumor','tumour'])

# %%
def list_of_words_2_spacy_patterns(list_of_words,
                                   nlp_model,
                                   label_name
                                  ):
    spacy_patterns = []
    for each_word in list_of_words:
        sub_pattern_list = [] # [{"ORTH": user_text_entity_df.loc[each_pattern_index,'TEXT']}]
        for token in  nlp_model(each_word.lower()):
            if re.search('^\W{1,}$',token.text):
                sub_pattern_list.append({"ORTH": token.text,"OP":"*"})
            else:
                sub_pattern_list.append({"LOWER":token.text})
        temp_dict = {"label": label_name,
                     "pattern": sub_pattern_list}
        spacy_patterns.append(temp_dict)
    return spacy_patterns


def load_rules_nlp_model_from_spacy_patterns(spacy_patterns):
    rules_nlp = spacy.load('en_core_web_sm',disable=['ner'])
    rules_config = {
        "validate": True,
        "overwrite_ents": True,
    }

    disease_rules = rules_nlp.add_pipe("entity_ruler", # invoke entity_ruler pipe 
                                       "disease_rules", # give a name to the pipe
                                       config=rules_config)
    disease_rules.add_patterns(spacy_patterns)
    return rules_nlp

# %%
disease_spacy_rules_patterns = list_of_words_2_spacy_patterns(list_of_diseases,
                               nlp,
                               "DISEASE"
                              )

# %%
disease_ner_rules_nlp = load_rules_nlp_model_from_spacy_patterns(disease_spacy_rules_patterns)

# %%
disease_ner_rules_nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'disease_rules']

# %%
disease_ner_rules_nlp.pipe_labels['disease_rules']
# Out:
# ['DISEASE']

# %%
# !mkdir -p ../data/model_weights/spacy_rules
# !mkdir -p ../data/model_weights/spacy_rules_packaged_model/

# %%
disease_ner_rules_nlp.to_disk('../data/model_weights/spacy_rules')

# %%
# !ls ../data/
# Out:
# conll_compatible_ner_data	diease_ner    ner_sentences_level_data
# conll_spacy_tokenized_ner_data	model_config

# %%
# !python -m spacy package ../data/model_weights/spacy_rules/ ../data/model_weights/spacy_rules_packaged_model/ --name disease_ner_rules
# Out:
# ℹ Building package artifacts: sdist
# ✔ Loaded meta.json from file
# ../data/model_weights/spacy_rules/meta.json
# ✔ Generated README.md from meta.json
# ✔ Successfully created package directory
# 'en_disease_ner_rules-3.3.0'
# ../data/model_weights/spacy_rules_packaged_model/en_disease_ner_rules-3.3.0
# running sdist
# running egg_info
# creating en_disease_ner_rules.egg-info
# writing en_disease_ner_rules.egg-info/PKG-INFO
# writing dependency_links to en_disease_ner_rules.egg-info/dependency_links.txt
# writing entry points to en_disease_ner_rules.egg-info/entry_points.txt
# writing requirements to en_disease_ner_rules.egg-info/requires.txt
# writing top-level names to en_disease_ner_rules.egg-info/top_level.txt
# writing manifest file 'en_disease_ner_rules.egg-info/SOURCES.txt'
# reading manifest file 'en_disease_ner_rules.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'en_disease_ner_rules.egg-info/SOURCES.txt'
# running check
# creating en_disease_ner_rules-3.3.0
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/attribute_ruler
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/disease_rules
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/lemmatizer
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/lemmatizer/lookups
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/ner
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/parser
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/senter
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/tagger
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/tok2vec
# creating en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab
# copying files to en_disease_ner_rules-3.3.0...
# copying MANIFEST.in -> en_disease_ner_rules-3.3.0
# copying README.md -> en_disease_ner_rules-3.3.0
# copying meta.json -> en_disease_ner_rules-3.3.0
# copying setup.py -> en_disease_ner_rules-3.3.0
# copying en_disease_ner_rules/__init__.py -> en_disease_ner_rules-3.3.0/en_disease_ner_rules
# copying en_disease_ner_rules/meta.json -> en_disease_ner_rules-3.3.0/en_disease_ner_rules
# copying en_disease_ner_rules.egg-info/PKG-INFO -> en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# copying en_disease_ner_rules.egg-info/SOURCES.txt -> en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# copying en_disease_ner_rules.egg-info/dependency_links.txt -> en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# copying en_disease_ner_rules.egg-info/entry_points.txt -> en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# copying en_disease_ner_rules.egg-info/not-zip-safe -> en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# copying en_disease_ner_rules.egg-info/requires.txt -> en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# copying en_disease_ner_rules.egg-info/top_level.txt -> en_disease_ner_rules-3.3.0/en_disease_ner_rules.egg-info
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/README.md -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/config.cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/meta.json -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/tokenizer -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/attribute_ruler/patterns -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/attribute_ruler
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/disease_rules/cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/disease_rules
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/disease_rules/patterns.jsonl -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/disease_rules
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/lemmatizer/lookups/lookups.bin -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/lemmatizer/lookups
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/ner/cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/ner
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/ner/model -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/ner
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/ner/moves -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/ner
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/parser/cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/parser
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/parser/model -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/parser
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/parser/moves -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/parser
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/senter/cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/senter
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/senter/model -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/senter
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/tagger/cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/tagger
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/tagger/model -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/tagger
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/tok2vec/cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/tok2vec
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/tok2vec/model -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/tok2vec
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab/key2row -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab/lookups.bin -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab/strings.json -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab/vectors -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab
# copying en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab/vectors.cfg -> en_disease_ner_rules-3.3.0/en_disease_ner_rules/en_disease_ner_rules-3.3.0/vocab
# Writing en_disease_ner_rules-3.3.0/setup.cfg
# creating dist
# Creating tar archive
# removing 'en_disease_ner_rules-3.3.0' (and everything under it)
# ✔ Successfully created zipped Python package
# ../data/model_weights/spacy_rules_packaged_model/en_disease_ner_rules-3.3.0/dist/en_disease_ner_rules-3.3.0.tar.gz

# %%
sentences_df.tail()
# Out:
#      New_Sentence_Id                                           Sentence
# 7293          tes_95  Deletion mapping studies have unambiguously id...
# 7294          tes_96  A new tumor suppressor gene , PTEN / MMAC1 , w...
# 7295          tes_97  We screened 80 prostate tumors by microsatelli...
# 7296          tes_98  We then proceeded with sequence analysis of th...
# 7297          tes_99  The identification of the second mutational ev...

# %%
sentences_df.shape
# Out:
# (7298, 2)

# %%
sentences_df.isnull().sum()
# Out:
# New_Sentence_Id    0
# Sentence           3
# dtype: int64

# %%
sentences_df.dropna(subset=['Sentence'],axis=0,inplace=True)

# %%
sentences_df.reset_index(drop=True,inplace=True)
sentences_df.isnull().sum()
# Out:
# New_Sentence_Id    0
# Sentence           0
# dtype: int64

# %%
sentences_df.shape
# Out:
# (7295, 2)

# %% [markdown]
# ### Prepare rules output NER

# %%
sentences_ids_tuples = list(zip(sentences_df['Sentence'],sentences_df['New_Sentence_Id']))

# %%
# %%time
token_tag_tuples = []
for i, (doc, doc_id) in enumerate(disease_ner_rules_nlp.pipe(sentences_ids_tuples,
                                                           as_tuples=True,
                                                           batch_size=100,
                                                          )                                
                               ):    
    if i%100 == 0:
        print(f"Process {i} sentences")
    for token in doc:
        token_ent_type = 'O' if token.ent_type_ == '' else token.ent_type_
        token_tag_tuples.append((doc_id,token.text,token_ent_type))
    token_tag_tuples.append((doc_id, '[SEP]', '[SEP]'))
# Out:
# Process 0 sentences
# Process 100 sentences
# Process 200 sentences
# Process 300 sentences
# Process 400 sentences
# Process 500 sentences
# Process 600 sentences
# Process 700 sentences
# Process 800 sentences
# Process 900 sentences
# Process 1000 sentences
# Process 1100 sentences
# Process 1200 sentences
# Process 1300 sentences
# Process 1400 sentences
# Process 1500 sentences
# Process 1600 sentences
# Process 1700 sentences
# Process 1800 sentences
# Process 1900 sentences
# Process 2000 sentences
# Process 2100 sentences
# Process 2200 sentences
# Process 2300 sentences
# Process 2400 sentences
# Process 2500 sentences
# Process 2600 sentences
# Process 2700 sentences
# Process 2800 sentences
# Process 2900 sentences
# Process 3000 sentences
# Process 3100 sentences
# Process 3200 sentences
# Process 3300 sentences
# Process 3400 sentences
# Process 3500 sentences
# Process 3600 sentences
# Process 3700 sentences
# Process 3800 sentences
# Process 3900 sentences
# Process 4000 sentences
# Process 4100 sentences
# Process 4200 sentences
# Process 4300 sentences
# Process 4400 sentences
# Process 4500 sentences
# Process 4600 sentences
# Process 4700 sentences
# Process 4800 sentences
# Process 4900 sentences
# Process 5000 sentences
# Process 5100 sentences
# Process 5200 sentences
# Process 5300 sentences
# Process 5400 sentences
# Process 5500 sentences
# Process 5600 sentences
# Process 5700 sentences
# Process 5800 sentences
# Process 5900 sentences
# Process 6000 sentences
# Process 6100 sentences
# Process 6200 sentences
# Process 6300 sentences
# Process 6400 sentences
# Process 6500 sentences
# Process 6600 sentences
# Process 6700 sentences
# Process 6800 sentences
# Process 6900 sentences
# Process 7000 sentences
# Process 7100 sentences
# Process 7200 sentences
# CPU times: user 20.4 s, sys: 186 ms, total: 20.5 s
# Wall time: 20.5 s

# %%
token_tag_df = pd.DataFrame(token_tag_tuples,columns=['New_Sentence_Id','Token','Rules_Tag'])

# %%
def convert_token_df_2_conll_format(token_tag_df,
                                    token_column_name,
                                    tag_column_name
                                   ):
    new_tag_column_name = tag_column_name + '_BIO'
    token_tag_df[new_tag_column_name] = ''
    # token_string = ''
    previous_tag_string = 'O'
    for each in range(len(token_tag_df)):
        if each %1000 == 0:
            print(f"{each} tokens processed")
        current_token_string = str(token_tag_df.loc[each,token_column_name])
        current_tag_string = str(token_tag_df.loc[each,tag_column_name])
        
        if current_token_string !='[SEP]':
            if previous_tag_string == 'O':
                if current_tag_string != 'O':
                    current_line = current_token_string + "\t" + "B-" + current_tag_string + "\n"
                else:
                    current_line = current_token_string + "\t" + current_tag_string + "\n"
            else:
                if current_tag_string == previous_tag_string:
                    current_line = current_token_string + "\t" + "I-" + current_tag_string + "\n"
                else:
                    if current_tag_string != 'O':
                        current_line = current_token_string + "\t" + "B-" + current_tag_string + "\n"
                    else:
                        current_line = current_token_string + "\t" + current_tag_string + "\n"
                        
            token_tag_df.loc[each,new_tag_column_name] = current_line.strip().split("\t")[1]
        else:
            current_line = "\n"
            token_tag_df.loc[each,new_tag_column_name] = '[SEP]'
        # token_string = token_string + current_line
        previous_tag_string = current_tag_string
        
    return token_tag_df

# %%
# %%time 
token_tag_df_2 = convert_token_df_2_conll_format(token_tag_df,
                                                    'Token',
                                                    'Rules_Tag'
                                                   )
# Out:
# 0 tokens processed
# 1000 tokens processed
# 2000 tokens processed
# 3000 tokens processed
# 4000 tokens processed
# 5000 tokens processed
# 6000 tokens processed
# 7000 tokens processed
# 8000 tokens processed
# 9000 tokens processed
# 10000 tokens processed
# 11000 tokens processed
# 12000 tokens processed
# 13000 tokens processed
# 14000 tokens processed
# 15000 tokens processed
# 16000 tokens processed
# 17000 tokens processed
# 18000 tokens processed
# 19000 tokens processed
# 20000 tokens processed
# 21000 tokens processed
# 22000 tokens processed
# 23000 tokens processed
# 24000 tokens processed
# 25000 tokens processed
# 26000 tokens processed
# 27000 tokens processed
# 28000 tokens processed
# 29000 tokens processed
# 30000 tokens processed
# 31000 tokens processed
# 32000 tokens processed
# 33000 tokens processed
# 34000 tokens processed
# 35000 tokens processed
# 36000 tokens processed
# 37000 tokens processed
# 38000 tokens processed
# 39000 tokens processed
# 40000 tokens processed
# 41000 tokens processed
# 42000 tokens processed
# 43000 tokens processed
# 44000 tokens processed
# 45000 tokens processed
# 46000 tokens processed
# 47000 tokens processed
# 48000 tokens processed
# 49000 tokens processed
# 50000 tokens processed
# 51000 tokens processed
# 52000 tokens processed
# 53000 tokens processed
# 54000 tokens processed
# 55000 tokens processed
# 56000 tokens processed
# 57000 tokens processed
# 58000 tokens processed
# 59000 tokens processed
# 60000 tokens processed
# 61000 tokens processed
# 62000 tokens processed
# 63000 tokens processed
# 64000 tokens processed
# 65000 tokens processed
# 66000 tokens processed
# 67000 tokens processed
# 68000 tokens processed
# 69000 tokens processed
# 70000 tokens processed
# 71000 tokens processed
# 72000 tokens processed
# 73000 tokens processed
# 74000 tokens processed
# 75000 tokens processed
# 76000 tokens processed
# 77000 tokens processed
# 78000 tokens processed
# 79000 tokens processed
# 80000 tokens processed
# 81000 tokens processed
# 82000 tokens processed
# 83000 tokens processed
# 84000 tokens processed
# 85000 tokens processed
# 86000 tokens processed
# 87000 tokens processed
# 88000 tokens processed
# 89000 tokens processed
# 90000 tokens processed
# 91000 tokens processed
# 92000 tokens processed
# 93000 tokens processed
# 94000 tokens processed
# 95000 tokens processed
# 96000 tokens processed
# 97000 tokens processed
# 98000 tokens processed
# 99000 tokens processed
# 100000 tokens processed
# 101000 tokens processed
# 102000 tokens processed
# 103000 tokens processed
# 104000 tokens processed
# 105000 tokens processed
# 106000 tokens processed
# 107000 tokens processed
# 108000 tokens processed
# 109000 tokens processed
# 110000 tokens processed
# 111000 tokens processed
# 112000 tokens processed
# 113000 tokens processed
# 114000 tokens processed
# 115000 tokens processed
# 116000 tokens processed
# 117000 tokens processed
# 118000 tokens processed
# 119000 tokens processed
# 120000 tokens processed
# 121000 tokens processed
# 122000 tokens processed
# 123000 tokens processed
# 124000 tokens processed
# 125000 tokens processed
# 126000 tokens processed
# 127000 tokens processed
# 128000 tokens processed
# 129000 tokens processed
# 130000 tokens processed
# 131000 tokens processed
# 132000 tokens processed
# 133000 tokens processed
# 134000 tokens processed
# 135000 tokens processed
# 136000 tokens processed
# 137000 tokens processed
# 138000 tokens processed
# 139000 tokens processed
# 140000 tokens processed
# 141000 tokens processed
# 142000 tokens processed
# 143000 tokens processed
# 144000 tokens processed
# 145000 tokens processed
# 146000 tokens processed
# 147000 tokens processed
# 148000 tokens processed
# 149000 tokens processed
# 150000 tokens processed
# 151000 tokens processed
# 152000 tokens processed
# 153000 tokens processed
# 154000 tokens processed
# 155000 tokens processed
# 156000 tokens processed
# 157000 tokens processed
# 158000 tokens processed
# 159000 tokens processed
# 160000 tokens processed
# 161000 tokens processed
# 162000 tokens processed
# 163000 tokens processed
# 164000 tokens processed
# 165000 tokens processed
# 166000 tokens processed
# 167000 tokens processed
# 168000 tokens processed
# 169000 tokens processed
# 170000 tokens processed
# 171000 tokens processed
# 172000 tokens processed
# 173000 tokens processed
# 174000 tokens processed
# 175000 tokens processed
# 176000 tokens processed
# 177000 tokens processed
# 178000 tokens processed
# 179000 tokens processed
# 180000 tokens processed
# 181000 tokens processed
# 182000 tokens processed
# 183000 tokens processed
# 184000 tokens processed
# 185000 tokens processed
# 186000 tokens processed
# 187000 tokens processed
# 188000 tokens processed
# 189000 tokens processed
# 190000 tokens processed
# 191000 tokens processed
# CPU times: user 9min 1s, sys: 331 ms, total: 9min 1s
# Wall time: 9min 1s

# %%
token_tag_df_2.head()
# Out:
#   New_Sentence_Id           Token Rules_Tag Rules_Tag_BIO
# 0            tr_0  Identification         O             O
# 1            tr_0              of         O             O
# 2            tr_0            APC2         O             O
# 3            tr_0               ,         O             O
# 4            tr_0               a         O             O

# %%
SPACY_RULES_NER_DIR = '../data/diease_ner/rules_ner'
# !mkdir -p $SPACY_RULES_NER_DIR
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
token_tag_df_2.to_csv(f'{SPACY_RULES_NER_DIR}/token_level_spacy_rules_ner_output.csv',index=None)

# %%
token_tag_df_2.head(25)
# Out:
#    New_Sentence_Id           Token Rules_Tag Rules_Tag_BIO
# 0             tr_0  Identification         O             O
# 1             tr_0              of         O             O
# 2             tr_0            APC2         O             O
# 3             tr_0               ,         O             O
# 4             tr_0               a         O             O
# 5             tr_0       homologue         O             O
# 6             tr_0              of         O             O
# 7             tr_0             the         O             O
# 8             tr_0     adenomatous   DISEASE     B-DISEASE
# 9             tr_0       polyposis   DISEASE     I-DISEASE
# 10            tr_0            coli   DISEASE     I-DISEASE
# 11            tr_0          tumour         O             O
# 12            tr_0      suppressor         O             O
# 13            tr_0               .         O             O
# 14            tr_0           [SEP]     [SEP]         [SEP]
# 15            tr_1             The         O             O
# 16            tr_1     adenomatous   DISEASE     B-DISEASE
# 17            tr_1       polyposis   DISEASE     I-DISEASE
# 18            tr_1            coli   DISEASE     I-DISEASE
# 19            tr_1               (         O             O
# 20            tr_1             APC   DISEASE     B-DISEASE
# 21            tr_1               )         O             O
# 22            tr_1          tumour         O             O
# 23            tr_1               -         O             O
# 24            tr_1      suppressor         O             O

# %% [markdown]
# ### Adding human annotated tags

# %%
SPACY_RULES_NER_DIR = '../data/diease_ner/rules_ner'

token_tag_df_2 = pd.read_csv(f'{SPACY_RULES_NER_DIR}/token_level_spacy_rules_ner_output.csv',index_col=False)

# %%
token_tag_df_2[token_tag_df_2['New_Sentence_Id'] == 'tr_1007']
# Out:
#     New_Sentence_Id        Token Rules_Tag Rules_Tag_BIO
# 205         tr_1007  Chromosomal         O             O
# 206         tr_1007     analysis         O             O
# 207         tr_1007          was         O             O
# 208         tr_1007       normal         O             O
# 209         tr_1007            (         O             O
# 210         tr_1007           46         O             O
# 211         tr_1007            ,         O             O
# 212         tr_1007           XY         O             O
# 213         tr_1007            )         O             O
# 214         tr_1007            .         O             O
# 215         tr_1007        [SEP]     [SEP]         [SEP]

# %%
SPACY_TOKENIZED_DIR = '../data/diease_ner/conll_spacy_tokenized_ner_data/'
final_token_level_annotated_data = pd.read_csv(f'{SPACY_TOKENIZED_DIR}/token_level_annotated_data.csv',index_col=False)

# %%
final_token_level_annotated_data[final_token_level_annotated_data['New_Sentence_Id'] == 'tr_1007']
# Out:
#       New_Sentence_Id Spacy_Small_Tokens Human_Annotated_Tag_BIO
# 26281         tr_1007        Chromosomal                       O
# 26282         tr_1007           analysis                       O
# 26283         tr_1007                was                       O
# 26284         tr_1007             normal                       O
# 26285         tr_1007                  (                       O
# 26286         tr_1007                 46                       O
# 26287         tr_1007                  ,                       O
# 26288         tr_1007                 XY                       O
# 26289         tr_1007                  )                       O
# 26290         tr_1007                  .                       O
# 26291         tr_1007              [SEP]                   [SEP]

# %%
final_token_level_annotated_data.columns = ['New_Sentence_Id', 'Token','Human_Annotated_Tag_BIO']

# %%
final_token_level_annotated_data['New_index'] = [every for every in range(len(final_token_level_annotated_data))]
final_token_level_annotated_data['New_index'] = final_token_level_annotated_data['New_index'].astype(str)
final_token_level_annotated_data['New_Spacy_Tokens'] = final_token_level_annotated_data['New_index'] + final_token_level_annotated_data['Token']

# %%
final_token_level_annotated_data.head()
# Out:
#   New_Sentence_Id           Token Human_Annotated_Tag_BIO New_index  \
# 0            tr_0  Identification                       O         0
# 1            tr_0              of                       O         1
# 2            tr_0            APC2                       O         2
# 3            tr_0               ,                       O         3
# 4            tr_0               a                       O         4
#
#   New_Spacy_Tokens
# 0  0Identification
# 1              1of
# 2            2APC2
# 3               3,
# 4               4a

# %%
final_token_level_annotated_data.sort_values(by=['New_Sentence_Id','New_Spacy_Tokens'],inplace=True)

# %%
final_token_level_annotated_data.reset_index(drop=True,inplace=True)

# %%
final_token_level_annotated_data[final_token_level_annotated_data['New_Sentence_Id'] == 'tr_1007']
# Out:
#       New_Sentence_Id        Token Human_Annotated_Tag_BIO New_index  \
# 25685         tr_1007  Chromosomal                       O     26281
# 25686         tr_1007     analysis                       O     26282
# 25687         tr_1007          was                       O     26283
# 25688         tr_1007       normal                       O     26284
# 25689         tr_1007            (                       O     26285
# 25690         tr_1007           46                       O     26286
# 25691         tr_1007            ,                       O     26287
# 25692         tr_1007           XY                       O     26288
# 25693         tr_1007            )                       O     26289
# 25694         tr_1007            .                       O     26290
# 25695         tr_1007        [SEP]                   [SEP]     26291
#
#        New_Spacy_Tokens
# 25685  26281Chromosomal
# 25686     26282analysis
# 25687          26283was
# 25688       26284normal
# 25689            26285(
# 25690           2628646
# 25691            26287,
# 25692           26288XY
# 25693            26289)
# 25694            26290.
# 25695        26291[SEP]

# %%
token_tag_df_2['New_index'] = [every for every in range(len(token_tag_df_2))]
token_tag_df_2['New_index'] = token_tag_df_2['New_index'].astype(str)
token_tag_df_2['New_Spacy_Tokens'] = token_tag_df_2['New_index'] + token_tag_df_2['Token']
token_tag_df_2.sort_values(by=['New_Sentence_Id','New_Spacy_Tokens'],inplace=True)
token_tag_df_2.reset_index(drop=True,inplace=True)

# %%
token_tag_df_2[token_tag_df_2['New_Sentence_Id'] == 'tr_1007']
# Out:
#       New_Sentence_Id        Token Rules_Tag Rules_Tag_BIO New_index  \
# 25685         tr_1007  Chromosomal         O             O       205
# 25686         tr_1007     analysis         O             O       206
# 25687         tr_1007          was         O             O       207
# 25688         tr_1007       normal         O             O       208
# 25689         tr_1007            (         O             O       209
# 25690         tr_1007           46         O             O       210
# 25691         tr_1007            ,         O             O       211
# 25692         tr_1007           XY         O             O       212
# 25693         tr_1007            )         O             O       213
# 25694         tr_1007            .         O             O       214
# 25695         tr_1007        [SEP]     [SEP]         [SEP]       215
#
#       New_Spacy_Tokens
# 25685   205Chromosomal
# 25686      206analysis
# 25687           207was
# 25688        208normal
# 25689             209(
# 25690            21046
# 25691             211,
# 25692            212XY
# 25693             213)
# 25694             214.
# 25695         215[SEP]

# %%
final_token_tag_df = pd.concat([token_tag_df_2[['New_Sentence_Id','Token','Rules_Tag_BIO']], 
                                final_token_level_annotated_data[['Human_Annotated_Tag_BIO']]],axis=1)

# %%
final_token_tag_df[final_token_tag_df['New_Sentence_Id']== 'tr_1007']
# Out:
#       New_Sentence_Id        Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 25685         tr_1007  Chromosomal             O                       O
# 25686         tr_1007     analysis             O                       O
# 25687         tr_1007          was             O                       O
# 25688         tr_1007       normal             O                       O
# 25689         tr_1007            (             O                       O
# 25690         tr_1007           46             O                       O
# 25691         tr_1007            ,             O                       O
# 25692         tr_1007           XY             O                       O
# 25693         tr_1007            )             O                       O
# 25694         tr_1007            .             O                       O
# 25695         tr_1007        [SEP]         [SEP]                   [SEP]

# %%
final_token_tag_df.head(50)
# Out:
#    New_Sentence_Id           Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 0            tes_0      Clustering             O                       O
# 1            tes_0              of             O                       O
# 2            tes_0        missense             O                       O
# 3            tes_0       mutations             O                       O
# 4            tes_0              in             O                       O
# 5            tes_0             the             O                       O
# 6            tes_0          ataxia             O               B-Disease
# 7            tes_0               -             O               I-Disease
# 8            tes_0  telangiectasia             O               I-Disease
# 9            tes_0            gene             O                       O
# 10           tes_0              in             O                       O
# 11           tes_0               a             O                       O
# 12           tes_0        sporadic             O               B-Disease
# 13           tes_0               T             O               I-Disease
# 14           tes_0               -             O               I-Disease
# 15           tes_0            cell             O               I-Disease
# 16           tes_0       leukaemia             O               I-Disease
# 17           tes_0               .             O                       O
# 18           tes_0           [SEP]         [SEP]                   [SEP]
# 19           tes_1          Ataxia             O               B-Disease
# 20           tes_1               -             O               I-Disease
# 21           tes_1  telangiectasia             O               I-Disease
# 22           tes_1               (             O                       O
# 23           tes_1               A             O               B-Disease
# 24           tes_1               -             O               I-Disease
# 25           tes_1               T             O               I-Disease
# 26           tes_1               )             O                       O
# 27           tes_1              is             O                       O
# 28           tes_1               a             O                       O
# 29           tes_1       recessive             O               B-Disease
# 30           tes_1           multi             O               I-Disease
# 31           tes_1               -             O               I-Disease
# 32           tes_1          system             O               I-Disease
# 33           tes_1        disorder             O               I-Disease
# 34           tes_1          caused             O                       O
# 35           tes_1              by             O                       O
# 36           tes_1       mutations             O                       O
# 37           tes_1              in             O                       O
# 38           tes_1             the             O                       O
# 39           tes_1             ATM             O                       O
# 40           tes_1            gene             O                       O
# 41           tes_1              at             O                       O
# 42           tes_1           11q22             O                       O
# 43           tes_1               -             O                       O
# 44           tes_1             q23             O                       O
# 45           tes_1               (             O                       O
# 46           tes_1             ref             O                       O
# 47           tes_1               .             O                       O
# 48           tes_1               3             O                       O
# 49           tes_1               )             O                       O

# %%
final_token_tag_df['Human_Annotated_Tag_BIO'] = final_token_tag_df['Human_Annotated_Tag_BIO'].str.upper()

# %%
# !mkdir -p ../data/diease_ner/output/

# %%
final_token_tag_df.to_csv('../data/diease_ner/output/token_level_annotated_rules_data.csv',index=None)

# %%
final_token_tag_df.tail(35)
# Out:
#        New_Sentence_Id       Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 191942          val_99         was             O                       O
# 191943          val_99       found             O                       O
# 191944          val_99          in             O                       O
# 191945          val_99        five             O                       O
# 191946          val_99    families             O                       O
# 191947          val_99           ,             O                       O
# 191948          val_99         the             O                       O
# 191949          val_99           C             O                       O
# 191950          val_99        1806             O                       O
# 191951          val_99           T             O                       O
# 191952          val_99    nonsense             O                       O
# 191953          val_99    mutation             O                       O
# 191954          val_99          in             O                       O
# 191955          val_99       three             O                       O
# 191956          val_99    families             O                       O
# 191957          val_99           ,             O                       O
# 191958          val_99         the             O                       O
# 191959          val_99        3166             O                       O
# 191960          val_99   insertion             O                       O
# 191961          val_99       TGAGA             O                       O
# 191962          val_99          in             O                       O
# 191963          val_99       three             O                       O
# 191964          val_99    families             O                       O
# 191965          val_99           ,             O                       O
# 191966          val_99         and             O                       O
# 191967          val_99         the             O                       O
# 191968          val_99  nucleotide             O                       O
# 191969          val_99        1201             O                       O
# 191970          val_99    deletion             O                       O
# 191971          val_99          11             O                       O
# 191972          val_99          in             O                       O
# 191973          val_99         two             O                       O
# 191974          val_99    families             O                       O
# 191975          val_99           .             O                       O
# 191976          val_99       [SEP]         [SEP]                   [SEP]

# %% [markdown]
# ### Aggregate the labels at sentence level

# %% [markdown]
# **Types of Sentences based on entities**

# %%
final_token_tag_df_2 = final_token_tag_df.copy()

final_token_tag_df_2 = final_token_tag_df_2[final_token_tag_df_2['Token'] != '[SEP]']

# %%
final_token_tag_df_2[final_token_tag_df_2['Human_Annotated_Tag_BIO']== '[SEP]']
# Out:
#        New_Sentence_Id        Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 25588           tr_100       levels             O                   [SEP]
# 26509          tr_1035  ventilatory             O                   [SEP]
# 35490          tr_1339           be             O                   [SEP]
# 82607             tr_3            ,             O                   [SEP]
# 103257           tr_37     activity             O                   [SEP]
# 107395         tr_3836           22             O                   [SEP]
# 107507          tr_384         less             O                   [SEP]
# 125489         tr_4481           to             O                   [SEP]

# %%
final_token_tag_df_2['Human_Annotated_Tag_BIO'] = final_token_tag_df_2['Human_Annotated_Tag_BIO'].apply(lambda x: x if x!='[SEP]' else 'O')

# %%
final_token_tag_df_2[final_token_tag_df_2['Human_Annotated_Tag_BIO']== '[SEP]']
# Out:
# Empty DataFrame
# Columns: [New_Sentence_Id, Token, Rules_Tag_BIO, Human_Annotated_Tag_BIO]
# Index: []

# %%
# %%time

sentence_level_df = final_token_tag_df_2.groupby('New_Sentence_Id')['Human_Annotated_Tag_BIO']\
.apply(lambda x: "|".join(
    list(set(sorted(x)))
))

N = len(sentence_level_df)

sentence_level_df = pd.DataFrame(sentence_level_df).reset_index()

sentence_level_df = sentence_level_df[sentence_level_df['New_Sentence_Id'] != '[SEP]']

sentence_level_df.reset_index(drop=True,inplace=True)

sentence_level_count_df = pd.DataFrame(sentence_level_df['Human_Annotated_Tag_BIO'].value_counts()).reset_index()
sentence_level_count_df.columns = ['Sentence_level_tags','Count']
sentence_level_count_df['%_contribution'] = round(sentence_level_count_df['Count']/len(sentence_level_df) * 100.0)


sentence_level_count_df
# Out:
# CPU times: user 146 ms, sys: 0 ns, total: 146 ms
# Wall time: 145 ms
#      Sentence_level_tags  Count  %_contribution
# 0                      O   3337            46.0
# 1  I-DISEASE|B-DISEASE|O   2698            37.0
# 2            B-DISEASE|O   1260            17.0

# %%
sentence_level_df.Human_Annotated_Tag_BIO.value_counts()
# Out:
# O                              3333
# I-DISEASE|B-DISEASE|O          2695
# B-DISEASE|O                    1259
# [SEP]|O                           4
# I-DISEASE|B-DISEASE|[SEP]|O       3
# B-DISEASE|[SEP]|O                 1
# Name: Human_Annotated_Tag_BIO, dtype: int64

# %%
sentence_level_count_df.to_csv('spacy_model_ner/split_of_classes_sentence_level.csv',index=None)

# %%
sentence_level_df.shape
# Out:
# (7295, 2)

# %%
sentence_level_df.head()
# Out:
#   New_Sentence_Id Human_Annotated_Tag_BIO
# 0           tes_0   B-DISEASE|I-DISEASE|O
# 1           tes_1   B-DISEASE|I-DISEASE|O
# 2          tes_10   B-DISEASE|I-DISEASE|O
# 3         tes_100   B-DISEASE|I-DISEASE|O
# 4         tes_101   B-DISEASE|I-DISEASE|O

# %% [markdown]
# Split the sentences into 80-10-10 train, dev and test datasets

# %%
from sklearn.model_selection import train_test_split

# %%
train_df,intermediate_df =  train_test_split(sentence_level_df,
                                             test_size=0.2, 
                                             stratify=sentence_level_df['Human_Annotated_Tag_BIO'],
                                             random_state=0)


dev_df, test_df = train_test_split(intermediate_df,
                                             test_size=0.5, 
                                             stratify=intermediate_df['Human_Annotated_Tag_BIO'],
                                             random_state=0)

# %%
train_df.head()
# Out:
#      New_Sentence_Id Human_Annotated_Tag_BIO
# 5354         tr_4971                       O
# 187          tes_267                       O
# 3577         tr_3371                       O
# 2366         tr_2281   I-DISEASE|B-DISEASE|O
# 655          tes_689             B-DISEASE|O

# %%
train_token_level_data = final_token_tag_df[final_token_tag_df['New_Sentence_Id'].isin(train_df['New_Sentence_Id'])]

# %%
final_token_tag_df.shape
# Out:
# (191977, 4)

# %%
train_token_level_data.shape
# Out:
# (154023, 4)

# %%
# !mkdir -p ../data/diease_ner/train_dev_test_split/

# %%
train_token_level_data.to_csv('../data/diease_ner/train_dev_test_split/train_token_level_df.csv', index=None)

# %%
train_token_level_data.tail()
# Out:
#        New_Sentence_Id     Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 191972          val_99        in             O                       O
# 191973          val_99       two             O                       O
# 191974          val_99  families             O                       O
# 191975          val_99         .             O                       O
# 191976          val_99     [SEP]         [SEP]                   [SEP]

# %%
dev_token_level_data = final_token_tag_df[final_token_tag_df['New_Sentence_Id'].isin(dev_df['New_Sentence_Id'])]
dev_token_level_data.to_csv('../data/diease_ner/train_dev_test_split/dev_token_level_df.csv', index=None)
dev_token_level_data.shape
# Out:
# (19203, 4)

# %%
test_token_level_data = final_token_tag_df[final_token_tag_df['New_Sentence_Id'].isin(test_df['New_Sentence_Id'])]
test_token_level_data.to_csv('../data/diease_ner/train_dev_test_split/test_token_level_df.csv', index=None)
test_token_level_data.shape
# Out:
# (18751, 4)

# %%
train_token_level_data.reset_index(drop=True,inplace=True)
dev_token_level_data.reset_index(drop=True,inplace=True)
test_token_level_data.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### Spacy ML Compatible Data

# %%
# !mkdir -p ../data/diease_ner/train_dev_test_split_conll_data/

# %%
train_token_level_data = pd.read_csv('../data/diease_ner/train_dev_test_split/train_token_level_df.csv',index_col=False)
dev_token_level_data = pd.read_csv('../data/diease_ner/train_dev_test_split/dev_token_level_df.csv',index_col=False)
test_token_level_data = pd.read_csv('../data/diease_ner/train_dev_test_split/test_token_level_df.csv',index_col=False)

# %%
train_token_level_data.head()
# Out:
#   New_Sentence_Id       Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 0           tes_0  Clustering             O                       O
# 1           tes_0          of             O                       O
# 2           tes_0    missense             O                       O
# 3           tes_0   mutations             O                       O
# 4           tes_0          in             O                       O

# %%
train_token_level_data['Human_Annotated_Tag_BIO'].value_counts()
# Out:
# O            136106
# I-DISEASE      6582
# [SEP]          5836
# B-DISEASE      5499
# Name: Human_Annotated_Tag_BIO, dtype: int64

# %%
def convert_token_df_2_conll_string(token_tag_df,
                                    token_column_name,
                                    tag_column_name
                                   ):
    token_string = ''
    for each in range(len(token_tag_df)):
        if each %1000 == 0:
            print(f"{each} tokens processed")
        current_token_string = str(token_tag_df.loc[each,token_column_name])
        current_tag_string = str(token_tag_df.loc[each,tag_column_name])
        if current_tag_string == 'EP]':
            current_tag_string = 'O'
        if current_token_string !='[SEP]':
            current_line = current_token_string + "\t" + current_tag_string + "\n"
        else:
            current_line = "\n"
        token_string = token_string + current_line
    return token_string

# %%
# %%time
test_conll_string = convert_token_df_2_conll_string(test_token_level_data,
                                'Token',
                                'Human_Annotated_Tag_BIO'
                               )
# Out:
# 0 tokens processed
# 1000 tokens processed
# 2000 tokens processed
# 3000 tokens processed
# 4000 tokens processed
# 5000 tokens processed
# 6000 tokens processed
# 7000 tokens processed
# 8000 tokens processed
# 9000 tokens processed
# 10000 tokens processed
# 11000 tokens processed
# 12000 tokens processed
# 13000 tokens processed
# 14000 tokens processed
# 15000 tokens processed
# 16000 tokens processed
# 17000 tokens processed
# 18000 tokens processed
# CPU times: user 324 ms, sys: 0 ns, total: 324 ms
# Wall time: 323 ms

# %%
test_token_level_data.head()
# Out:
#   New_Sentence_Id          Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 0         tes_102         Limits             O                       O
# 1         tes_102             to             O                       O
# 2         tes_102       accuracy             O                       O
# 3         tes_102       included             O                       O
# 4         tes_102  recombination             O                       O

# %%
with open('../data/diease_ner/train_dev_test_split_conll_data/test_data.conll','w',encoding='utf-8') as f:
    f.write(test_conll_string)

# %%
# !tail -n 25 ../data/diease_ner/train_dev_test_split_conll_data/test_data.conll
# Out:
# investigate	O
# the	O
# rate	O
# of	O
# BRCA2	O
# mutation	O
# in	O
# sporadic	B-DISEASE
# breast	I-DISEASE
# cancers	I-DISEASE
# and	O
# in	O
# a	O
# set	O
# of	O
# cell	O
# lines	O
# that	O
# represent	O
# twelve	O
# other	O
# tumour	B-DISEASE
# types	O
# .	O

# %%
# !wc -l ../data/diease_ner/train_dev_test_split_conll_data/test_data.conll
# Out:
# 18751 ../data/diease_ner/train_dev_test_split_conll_data/test_data.conll

# %%
# %%time
dev_conll_string = convert_token_df_2_conll_string(dev_token_level_data,
                                'Token',
                                'Human_Annotated_Tag_BIO'
                               )


with open('../data/diease_ner/train_dev_test_split_conll_data/dev_data.conll','w',encoding='utf-8') as f:
    f.write(dev_conll_string)
    
# !wc -l ../data/diease_ner/train_dev_test_split_conll_data/dev_data.conll
# Out:
# 0 tokens processed
# 1000 tokens processed
# 2000 tokens processed
# 3000 tokens processed
# 4000 tokens processed
# 5000 tokens processed
# 6000 tokens processed
# 7000 tokens processed
# 8000 tokens processed
# 9000 tokens processed
# 10000 tokens processed
# 11000 tokens processed
# 12000 tokens processed
# 13000 tokens processed
# 14000 tokens processed
# 15000 tokens processed
# 16000 tokens processed
# 17000 tokens processed
# 18000 tokens processed
# 19000 tokens processed
# 19203 ../data/diease_ner/train_dev_test_split_conll_data/dev_data.conll
# CPU times: user 341 ms, sys: 0 ns, total: 341 ms
# Wall time: 622 ms

# %%
# %%time
train_conll_string = convert_token_df_2_conll_string(train_token_level_data,
                                'Token',
                                'Human_Annotated_Tag_BIO'
                               )


with open('../data/diease_ner/train_dev_test_split_conll_data/train_data.conll','w',encoding='utf-8') as f:
    f.write(train_conll_string)
    
# !wc -l ../data/diease_ner/train_dev_test_split_conll_data/train_data.conll
# Out:
# 0 tokens processed
# 1000 tokens processed
# 2000 tokens processed
# 3000 tokens processed
# 4000 tokens processed
# 5000 tokens processed
# 6000 tokens processed
# 7000 tokens processed
# 8000 tokens processed
# 9000 tokens processed
# 10000 tokens processed
# 11000 tokens processed
# 12000 tokens processed
# 13000 tokens processed
# 14000 tokens processed
# 15000 tokens processed
# 16000 tokens processed
# 17000 tokens processed
# 18000 tokens processed
# 19000 tokens processed
# 20000 tokens processed
# 21000 tokens processed
# 22000 tokens processed
# 23000 tokens processed
# 24000 tokens processed
# 25000 tokens processed
# 26000 tokens processed
# 27000 tokens processed
# 28000 tokens processed
# 29000 tokens processed
# 30000 tokens processed
# 31000 tokens processed
# 32000 tokens processed
# 33000 tokens processed
# 34000 tokens processed
# 35000 tokens processed
# 36000 tokens processed
# 37000 tokens processed
# 38000 tokens processed
# 39000 tokens processed
# 40000 tokens processed
# 41000 tokens processed
# 42000 tokens processed
# 43000 tokens processed
# 44000 tokens processed
# 45000 tokens processed
# 46000 tokens processed
# 47000 tokens processed
# 48000 tokens processed
# 49000 tokens processed
# 50000 tokens processed
# 51000 tokens processed
# 52000 tokens processed
# 53000 tokens processed
# 54000 tokens processed
# 55000 tokens processed
# 56000 tokens processed
# 57000 tokens processed
# 58000 tokens processed
# 59000 tokens processed
# 60000 tokens processed
# 61000 tokens processed
# 62000 tokens processed
# 63000 tokens processed
# 64000 tokens processed
# 65000 tokens processed
# 66000 tokens processed
# 67000 tokens processed
# 68000 tokens processed
# 69000 tokens processed
# 70000 tokens processed
# 71000 tokens processed
# 72000 tokens processed
# 73000 tokens processed
# 74000 tokens processed
# 75000 tokens processed
# 76000 tokens processed
# 77000 tokens processed
# 78000 tokens processed
# 79000 tokens processed
# 80000 tokens processed
# 81000 tokens processed
# 82000 tokens processed
# 83000 tokens processed
# 84000 tokens processed
# 85000 tokens processed
# 86000 tokens processed
# 87000 tokens processed
# 88000 tokens processed
# 89000 tokens processed
# 90000 tokens processed
# 91000 tokens processed
# 92000 tokens processed
# 93000 tokens processed
# 94000 tokens processed
# 95000 tokens processed
# 96000 tokens processed
# 97000 tokens processed
# 98000 tokens processed
# 99000 tokens processed
# 100000 tokens processed
# 101000 tokens processed
# 102000 tokens processed
# 103000 tokens processed
# 104000 tokens processed
# 105000 tokens processed
# 106000 tokens processed
# 107000 tokens processed
# 108000 tokens processed
# 109000 tokens processed
# 110000 tokens processed
# 111000 tokens processed
# 112000 tokens processed
# 113000 tokens processed
# 114000 tokens processed
# 115000 tokens processed
# 116000 tokens processed
# 117000 tokens processed
# 118000 tokens processed
# 119000 tokens processed
# 120000 tokens processed
# 121000 tokens processed
# 122000 tokens processed
# 123000 tokens processed
# 124000 tokens processed
# 125000 tokens processed
# 126000 tokens processed
# 127000 tokens processed
# 128000 tokens processed
# 129000 tokens processed
# 130000 tokens processed
# 131000 tokens processed
# 132000 tokens processed
# 133000 tokens processed
# 134000 tokens processed
# 135000 tokens processed
# 136000 tokens processed
# 137000 tokens processed
# 138000 tokens processed
# 139000 tokens processed
# 140000 tokens processed
# 141000 tokens processed
# 142000 tokens processed
# 143000 tokens processed
# 144000 tokens processed
# 145000 tokens processed
# 146000 tokens processed
# 147000 tokens processed
# 148000 tokens processed
# 149000 tokens processed
# 150000 tokens processed
# 151000 tokens processed
# 152000 tokens processed
# 153000 tokens processed
# 154000 tokens processed
# 154023 ../data/diease_ner/train_dev_test_split_conll_data/train_data.conll
# CPU times: user 2.66 s, sys: 0 ns, total: 2.66 s
# Wall time: 2.94 s

# %%
def count_of_tags(df,
                  name_of_file
                 ):
    df = pd.DataFrame(df['Human_Annotated_Tag_BIO'].value_counts()).reset_index()
    df.columns = ['Sentence_level_tags','Count']
    df['%_contribution'] = round(df['Count']/sum(df['Count']) * 100.0)
    df.to_csv(f'spacy_model_ner/{name_of_file}',index=None)
    return df

# %%
train_count_df = count_of_tags(train_df,name_of_file='split_of_classes_sentence_level_train.csv')
dev_count_df = count_of_tags(dev_df,name_of_file='split_of_classes_sentence_level_dev.csv')
test_count_df = count_of_tags(test_df,name_of_file='split_of_classes_sentence_level_test.csv')

# %%
train_count_df
# Out:
#      Sentence_level_tags  Count  %_contribution
# 0                      O   2670            46.0
# 1  I-DISEASE|B-DISEASE|O   2158            37.0
# 2            B-DISEASE|O   1008            17.0

# %%
dev_count_df
# Out:
#      Sentence_level_tags  Count  %_contribution
# 0                      O    333            46.0
# 1  I-DISEASE|B-DISEASE|O    270            37.0
# 2            B-DISEASE|O    126            17.0

# %%
test_count_df
# Out:
#      Sentence_level_tags  Count  %_contribution
# 0                      O    334            46.0
# 1  I-DISEASE|B-DISEASE|O    270            37.0
# 2            B-DISEASE|O    126            17.0

# %% [markdown]
# ### Appendix

# %%
new_df = token_tag_df_2[token_tag_df_2['New_Sentence_Id']=='tr_0']

# %%
new_df.to_csv('spacy_model_ner/token_level_tags_on_one_unlabeled_sentence.csv',index=None)

# %%
new_df_2 = final_token_tag_df[final_token_tag_df['New_Sentence_Id']=='tr_0']
new_df_2.to_csv('spacy_model_ner/token_level_tags_on_one_unlabeled_sentence_2.csv',index=None)

# %%
new_df_2
# Out:
#    New_Sentence_Id           Token Rules_Tag_BIO Human_Annotated_Tag_BIO
# 0             tr_0  Identification             O                       O
# 1             tr_0              of             O                       O
# 2             tr_0              of             O                       O
# 3             tr_0              of             O                       O
# 4             tr_0              of             O                       O
# 5             tr_0            APC2             O                       O
# 6             tr_0               ,             O                       O
# 7             tr_0               a             O                       O
# 8             tr_0       homologue             O                       O
# 9             tr_0             the             O                       O
# 10            tr_0     adenomatous     B-DISEASE               B-DISEASE
# 11            tr_0       polyposis     I-DISEASE               I-DISEASE
# 12            tr_0            coli     I-DISEASE               I-DISEASE
# 13            tr_0          tumour             O               I-DISEASE
# 14            tr_0      suppressor             O                       O
# 15            tr_0               .             O                       O
# 16            tr_0           [SEP]         [SEP]                   [SEP]
